# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %%
df=pd.read_csv('updated_cleaned_data.csv')

# %%
df.loc[df['City'] == 'ny',['Region', 'City', 'Price (€)', 'Living area (m²)']]
# Out:
#         Region City  Price (€)  Living area (m²)
# 10897  Walloon   ny      69000              40.0

# %%
# corr=df['Price (€)'].corr(df['Living area (m²)'])

# %%
# df_without_outliers = df.copy()
# def remove_outliers(df,columns,n_std):
#     for col in columns:
#         print('Working on column: {}'.format(col))

#         mean = df[col].mean()
#         sd = df[col].std()

#         df = df[(df[col] <= mean+(n_std*sd))]

#     return df
# std_col = ['Price (€)', 'Construction year', 'Bedrooms',
#        'Living area (m²)', 'Terrace surface (m²)', 'Garden surface (m²)',
#        'Surface of the plot (m²)', 'Number of frontages', 'Cadastral income (€)',
#        'Primary energy consumption (kWh/m²)', 'CO₂ emission (kg CO₂/m²)']
# df_without_outliers = remove_outliers(df_without_outliers, ['Price (€)'], 4)

# %%
plt.figure(figsize=(14,8))
sns.regplot(x=df["Living area (m²)"], y=df["Price (€)"])
plt.title('Living area vs. Price')
# Out:
# Text(0.5, 1.0, 'Living area vs. Price')

# %%
df_num_subset = df[['Price (€)', 'Construction year', 'Bedrooms',
       'Living area (m²)', 'Furnished', 'How many fireplaces?',
       'Terrace', 'Terrace surface (m²)', 'Garden', 'Garden surface (m²)',
       'Surface of the plot (m²)', 'Number of frontages', 'Swimming pool',
       'Elevator', 'Basement', 
       'Primary energy consumption (kWh/m²)', 'CO₂ emission (kg CO₂/m²)',
       'Kitchen type scale',
       'Building condition scale']]

# %%
sns.set_theme(style="white")
corr = df_num_subset.corr()
mask = np.triu(df_num_subset.corr())
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.color_palette("Blues")

sns.heatmap(corr, 
            mask=mask, 
            cmap=cmap, 
            vmax=.3, 
            center=0,
            square=True, 
            linewidths=3, 
            cbar_kws={"shrink": .5}
           )
# Out:
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   func(*args, **kwargs)
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Correlation between different variables
corr = df_num_subset.corr()
# Set up the matplotlib plot configuration
f, ax = plt.subplots(figsize=(20, 12))
# Generate a mask for upper traingle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Configure a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   func(*args, **kwargs)
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = df_num_subset.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.1g')
# Out:
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   func(*args, **kwargs)
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = df_num_subset.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   func(*args, **kwargs)
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = df_num_subset.corr()
heatmap = sns.heatmap(corr, cmap="coolwarm")
# Out:
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.draw()
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   func(*args, **kwargs)
# /Users/saidkardic/Desktop/immoweb_project/challenge-data-analysis/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.boxplot(df['Terrace surface (m²)']) 
plt.xlabel("Terrace surface (m²)") 
plt.ylabel('Surface (m²)') 
plt.title('Terrace surface Outliers') 
plt.show()

# %%
plt.title('Price outliers') 
plt.scatter(range(len(df['Price (€)'])), df['Price (€)'])
plt.xlabel("number of property") 
plt.ylabel('Price mln €') 
plt.show()

# %%
plt.title('Living Area outliers') 
plt.scatter(range(len(df['Living area (m²)'])), df['Living area (m²)'])
plt.xlabel("number of property") 
plt.ylabel('Living area (m²)') 
plt.show()

# %%
plt.title('Terrace surface outliers') 
plt.scatter(range(len(df['Terrace surface (m²)'])), df['Terrace surface (m²)'])
plt.xlabel("Number of property") 
plt.ylabel('Surface (m²)') 
plt.show()

# %%
plt.title('Garden surface outliers') 
plt.scatter(range(len(df['Garden surface (m²)'])), df['Garden surface (m²)'])
plt.xlabel("Number of property") 
plt.ylabel('Garden (m²)') 
plt.show()

# %%
plt.boxplot(df['Garden surface (m²)']) 
plt.xlabel("Garden surface (m²)") 
plt.ylabel('Surface (m²)') 
plt.title('Garden surface Outliers') 
plt.show()
